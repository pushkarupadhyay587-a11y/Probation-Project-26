# %%
import numpy as np

# %%
arr = np.random.randint(1,21,size=(3,3))

# %%
# 2.a :
print("entire array : \n",arr)
# Out:
# entire array :
#  [[13 18 11]
#  [19 12  4]
#  [ 5  7  4]]

# %%
# 2.b:
print("first row :",arr[0])
# Out:
# first row : [13 18 11]

# %%
# 2.c :
print("second column : ", arr[:,1])
# Out:
# second column :  [18 12  7]

# %%
# 2.d : 
print("element at positiion (2,2)",print(arr[2,2]))
# Out:
# 4
# element at positiion (2,2) None

# %%
#  2.e:
print("subarray containing first two rows and columns : \n",arr[:2,:2])
# Out:
# subarray containing first two rows and columns :
#  [[13 18]
#  [19 12]]

# %%
# 2.f :
arr[1,1] = 99 
print("modified array : \n",arr)
# Out:
# modified array :
#  [[13 18 11]
#  [19 99  4]
#  [ 5  7  4]]
