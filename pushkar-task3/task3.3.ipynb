# %%
import numpy as np

# %%
arr1 = np.random.randint(1,21,size=10)
arr2 = np.random.randint(1,21,size=10)

# %%
print("arr1 :",arr1)
print("arr2 :",arr2)
# Out:
# arr1 : [14 14  6  2  8  4 14 10 19 16]
# arr2 : [14 14 16  3  2 11 12 18 14 11]

# %% [markdown]
# # 3.a :

# %%
print("sum of two  arrays :",arr1+arr2)
# Out:
# sum of two  arrays : [28 28 22  5 10 15 26 28 33 27]

# %%
print("subtraction of two  arrays :",arr1-arr2)
# Out:
# subtraction of two  arrays : [  0   0 -10  -1   6  -7   2  -8   5   5]

# %%
print("multiplication of two  arrays :",arr1*arr2)
# Out:
# multiplication of two  arrays : [196 196  96   6  16  44 168 180 266 176]

# %%
print("division of two  arrays :",arr1/arr2)
# Out:
# division of two  arrays : [1.         1.         0.375      0.66666667 4.         0.36363636
#  1.16666667 0.55555556 1.35714286 1.45454545]

# %% [markdown]
# # 3.b :

# %%
sq_arr1 = arr1**2
print("squared array : ",sq_arr1)
# Out:
# squared array :  [196 196  36   4  64  16 196 100 361 256]

# %% [markdown]
# # 3.c :

# %%
print("dot product of two arrays :",np.dot(arr1,arr2))
# Out:
# dot product of two arrays : 1344

# %% [markdown]
# # 3.d :

# %%
print("sorteed arr2 : ",np.sort(arr2))
# Out:
# sorteed arr2 :  [ 2  3 11 11 12 14 14 14 16 18]
