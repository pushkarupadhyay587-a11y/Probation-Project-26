# %%
import pandas as pd 
import numpy as np

# %%
arr = np.random.randint(1,101,10)
s = pd.Series(arr)

# %%
print(s)
# Out:
# 0    99
# 1    20
# 2    74
# 3    17
# 4    55
# 5    30
# 6    61
# 7    35
# 8    41
# 9    94
# dtype: int32

# %%
print("first 5 elements : \n",s.head())
# Out:
# first 5 elements :
#  0    99
# 1    20
# 2    74
# 3    17
# 4    55
# dtype: int32

# %%
print("last 5 elements : \n",s.tail())
# Out:
# last 5 elements :
#  5    30
# 6    61
# 7    35
# 8    41
# 9    94
# dtype: int32

# %%
print("maximum value : ",s.max())
print("minimum value : ",s.min())
# Out:
# maximum value :  99
# minimum value :  17

# %%
print(s.to_list())
# Out:
# [99, 20, 74, 17, 55, 30, 61, 35, 41, 94]
